# %% [markdown]
# Connected to Python 3.8.9

# %%
#Conditional statements

age = int(input("How old are you? "))
if age > 17:
    print("You are of age! ")
    print("Here's a copy of GTA6 for you. ")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 4
#       1 # %%
#       2 #Conditional statements
# ----> 4 age = int(input("How old are you? "))
#       5 if age > 17:
#       6     print("You are of age! ")
#
# ValueError: invalid literal for int() with base 10: '\\18'

# %%
#Conditional statements

age = int(input("How old are you? "))
if age > 17:
    print("You are of age!")
    print("Here's a copy of GTA6 for you. ")
print("Next customer please!")
# Out:
# Cell was canceled due to an error in a previous cell.

# %%
#Conditional statements

age = int(input("How old are you? "))
if age > 17:
    print("You are of age!")
    print("Here's a copy of GTA6 for you. ")
print("Next customer please!")
# Out:
# You are of age!
# Here's a copy of GTA6 for you.
# Next customer please!

# %%
#Conditional statements

age = int(input("How old are you? "))
if age > 17:
    print("You are of age!")
    print("Here's a copy of GTA6 for you. ")
print("Next customer please!")
# Out:
# Next customer please!

# %% [markdown]
# No kernel connected
